# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Jupyter").getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://93472181810c:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %%sql
#
# CREATE NAMESPACE demo.reference_tables;

# %%
# %%sql
#
# CREATE TABLE demo.reference_tables.org2_nation (
#     nationkey BIGINT,
#     name      STRING
# ) USING iceberg;

# %%
# %%sql
#
# INSERT INTO demo.reference_tables.org2_nation VALUES
#     (1, 'FRANCE'),
#     (2, 'IRAN'),
#     (3, 'GERMANY');

# %%
# %%sql
#
# SELECT *
# FROM demo.reference_tables.org2_nation
# WHERE name == "IRAN";
# Out:
# +-----------+------+
# | nationkey | name |
# +-----------+------+
# |         2 | IRAN |
# +-----------+------+

# %%
# %%sql
#
# SELECT * FROM demo.reference_tables.org2_nation;
# Out:
# +-----------+---------+
# | nationkey |    name |
# +-----------+---------+
# |         1 |  FRANCE |
# |         2 |    IRAN |
# |         3 | GERMANY |
# +-----------+---------+

# %%
# %%sql
#
# SELECT COUNT(*) FROM demo.reference_tables.org2_nation;
# Out:
# +----------+
# | count(1) |
# +----------+
# |        3 |
# +----------+
